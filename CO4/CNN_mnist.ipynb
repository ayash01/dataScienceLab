# %%
import pandas as pd
from keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Dense, Flatten, ZeroPadding2D

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(len(x_train), 28, 28, 1)
x_test = x_test.reshape(len(x_test), 28, 28, 1)

x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_train = y_train.reshape(len(y_train), 1)
y_test = y_test.reshape(len(y_test), 1)

y_train.shape
# Out:
# (60000, 1)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
model = Sequential([
    ZeroPadding2D((2, 2), input_shape = (28, 28, 1)),
    Conv2D(6, (5,5), activation = "tanh", input_shape = (32, 32, 1)),
    
    AveragePooling2D((2, 2)),
    Conv2D(16, (5, 5), activation="tanh"),
    
    AveragePooling2D((2, 2)),
    Conv2D(120, (5, 5), activation="tanh"),
    
    Flatten(),
    
    Dense(84, activation="tanh"),
    Dense(10, activation="softmax")
])

model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

model.fit(x_train, y_train, epochs = 10, batch_size = 64, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 8s 4ms/step - loss: 0.2716 - accuracy: 0.9190 - val_loss: 0.1249 - val_accuracy: 0.9625
# Epoch 2/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0967 - accuracy: 0.9699 - val_loss: 0.0841 - val_accuracy: 0.9717
# Epoch 3/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0644 - accuracy: 0.9799 - val_loss: 0.0623 - val_accuracy: 0.9810
# Epoch 4/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0492 - accuracy: 0.9847 - val_loss: 0.0548 - val_accuracy: 0.9819
# Epoch 5/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0386 - accuracy: 0.9878 - val_loss: 0.0557 - val_accuracy: 0.9821
# Epoch 6/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.0483 - val_accuracy: 0.9842
# Epoch 7/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0259 - accuracy: 0.9917 - val_loss: 0.0443 - val_accuracy: 0.9844
# Epoch 8/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.0487 - val_accuracy: 0.9854
# Epoch 9/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0458 - val_accuracy: 0.9855
# Epoch 10/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.0489 - val_accuracy: 0.9844

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
test_accuracy
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0489 - accuracy: 0.9844
# 0.9843999743461609
